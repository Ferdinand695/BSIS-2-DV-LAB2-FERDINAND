# %% [markdown]
# <a href="https://colab.research.google.com/github/Ferdinand695/BSIS-2-DV-LAB2-FERDINAND/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Ferdinand695/dataset/main/Dinan.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  #Passengers
# 0           0  1949-01-01          112
# 1           1  1949-02-01          118
# 2           2  1949-03-01          132
# 3           3  1949-04-01          129
# 4           4  1949-05-01          121

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985' ,freq='D')

# %%
time_series_data = pd.Series(range(1,11))

# %%
df.head()
# Out:
#    Unnamed: 0        Date  #Passengers
# 0           0  1949-01-01          112
# 1           1  1949-02-01          118
# 2           2  1949-03-01          132
# 3           3  1949-04-01          129
# 4           4  1949-05-01          121

# %%
import matplotlib.pyplot as plt

# %%
time_series_data_trend = time_series_data + 0.5 * pd.Series(range(0,11))

# %%
df
# Out:
#      Unnamed: 0        Date  #Passengers
# 0             0  1949-01-01          112
# 1             1  1949-02-01          118
# 2             2  1949-03-01          132
# 3             3  1949-04-01          129
# 4             4  1949-05-01          121
# ..          ...         ...          ...
# 139         139  1960-08-01          606
# 140         140  1960-09-01          508
# 141         141  1960-10-01          461
# 142         142  1960-11-01          390
# 143         143  1960-12-01          432
#
# [144 rows x 3 columns]

# %%
time_series_data__seasonal = time_series_data + 2 * pd.Series([0,-11] * 5)

# %%
df
# Out:
#      Unnamed: 0        Date  #Passengers
# 0             0  1949-01-01          112
# 1             1  1949-02-01          118
# 2             2  1949-03-01          132
# 3             3  1949-04-01          129
# 4             4  1949-05-01          121
# ..          ...         ...          ...
# 139         139  1960-08-01          606
# 140         140  1960-09-01          508
# 141         141  1960-10-01          461
# 142         142  1960-11-01          390
# 143         143  1960-12-01          432
#
# [144 rows x 3 columns]

# %%
import numpy as np

# %%
df
# Out:
#      Unnamed: 0        Date  #Passengers
# 0             0  1949-01-01          112
# 1             1  1949-02-01          118
# 2             2  1949-03-01          132
# 3             3  1949-04-01          129
# 4             4  1949-05-01          121
# ..          ...         ...          ...
# 139         139  1960-08-01          606
# 140         140  1960-09-01          508
# 141         141  1960-10-01          461
# 142         142  1960-11-01          390
# 143         143  1960-12-01          432
#
# [144 rows x 3 columns]

# %%
df
# Out:
#      Unnamed: 0        Date  #Passengers
# 0             0  1949-01-01          112
# 1             1  1949-02-01          118
# 2             2  1949-03-01          132
# 3             3  1949-04-01          129
# 4             4  1949-05-01          121
# ..          ...         ...          ...
# 139         139  1960-08-01          606
# 140         140  1960-09-01          508
# 141         141  1960-10-01          461
# 142         142  1960-11-01          390
# 143         143  1960-12-01          432
#
# [144 rows x 3 columns]
